# %% [markdown]
# # Applied data science capston assignment 3 West Coast Vacation

# %% [markdown]
# Three cities are used in this mapping California, namely San Fracisco, Los Angeles, and San Diego to get the informaion og all its neighbors, and to run some clustering algos on it (with finding the best).

# %% [markdown]
# ### Part 1: Initializing Coordinates

# %% [markdown]
# I will first import some libraries that I'll use for this assignment

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %% [markdown]
# Then I'll create a geolocator object for each city

# %%
address_sf = 'San Francisco, CA, US'

geolocator_sf = Nominatim(user_agent="sf_explorer")
location_sf = geolocator_sf.geocode(address_sf)
latitude_sf = location_sf.latitude
longitude_sf = location_sf.longitude
print('The geograpical coordinate of San Francisco are {}, {}.'.format(latitude_sf, longitude_sf))
# Out:
# The geograpical coordinate of San Francisco are 37.7792808, -122.4192363.

# %%
address_la = 'Los Angeles, CA'

geolocator_la = Nominatim(user_agent="la_explorer")
location_la = geolocator_la.geocode(address_la)
latitude_la = location_la.latitude
longitude_la = location_la.longitude
print('The geograpical coordinate of Los Angeles are {}, {}.'.format(latitude_la, longitude_la))
# Out:
# The geograpical coordinate of Los Angeles are 34.0536834, -118.2427669.

# %%
address_sd = 'San Diego, CA'

geolocator_sd = Nominatim(user_agent="sd_explorer")
location_sd = geolocator_sd.geocode(address_sd)
latitude_sd = location_sd.latitude
longitude_sd = location_sd.longitude
print('The geograpical coordinate of San Diego are {}, {}.'.format(latitude_sd, longitude_sd))
# Out:
# The geograpical coordinate of San Diego are 32.7174209, -117.1627714.

# %% [markdown]
# ### Part 2: Scraping the Neighborhoods

# %% [markdown]
# I will now scrape wikipedia for the names of neighborhoods in each city

# %%
from bs4 import BeautifulSoup
import requests

# %%
source_sf = requests.get('https://en.wikipedia.org/wiki/List_of_neighborhoods_in_San_Francisco').text
source_la = requests.get('https://en.wikipedia.org/wiki/List_of_districts_and_neighborhoods_of_Los_Angeles').text
source_sd = requests.get('https://en.wikipedia.org/wiki/List_of_communities_and_neighborhoods_of_San_Diego').text

# %% [markdown]
# These wikipedia pages are quite different from each other. So, I'll use different approaches in scraping them.

# %% [markdown]
# #### I'll start with San Francisco

# %%
soup_sf = BeautifulSoup(source_sf, 'lxml')

# %% [markdown]
# The most reliable way to get neighbourhood names in San Francisco is to use h2 header

# %%
sf_hood_list = soup_sf.find_all('h2')

# %%
tag_list =[]
for tag in sf_hood_list:
    tag_list.append(tag.text)

# %% [markdown]
# By looking at this tag list, we can see that we need to get rid of '[edit]' string at the end of each of them and we also need to get rid of first item on the list(word 'contents') and last four items on the list (references, links, etc.) that are not the names of neighbourhood

# %%
tag_list = tag_list[1:-4]

# %%
sf_list = []
for item in tag_list:
    sf_list.append(item[0:-6])

# %% [markdown]
# Now that we have a clean list of all San Francisco Neighbourhoods, we can find their coordinates and create a list of lists with neighborhood names, latitudes, and longitudes. We'll first convert a list to pandas dataframe and then create new columns for longitude and latitude

# %%
sf_coordinates = pd.DataFrame(sf_list, columns =['Neighbourhood'])

# %%
sf_coordinates['Latitude']=0
sf_coordinates['Longitude']=0

# %%
for item in sf_coordinates['Neighbourhood']:
    address = '{}, San Francisco, CA, US'.format(item)
    geolocator_sf = Nominatim(user_agent="sf_explorer")
    location_sf = geolocator_sf.geocode(address)
    if location_sf is not None:
        sf_coordinates['Latitude'].loc[sf_coordinates['Neighbourhood']==item] = location_sf.latitude
        sf_coordinates['Longitude'].loc[sf_coordinates['Neighbourhood']==item] = location_sf.longitude
# Out:
# /Users/Anna/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sf_coordinates.head()
# Out:
#      Neighbourhood   Latitude   Longitude
# 0     Alamo Square  37.776357 -122.434694
# 1       Anza Vista  37.780836 -122.443149
# 2  Ashbury Heights   0.000000    0.000000
# 3      Balboa Park  37.724949 -122.444805
# 4   Balboa Terrace   0.000000    0.000000

# %%
sf_coordinates.tail()
# Out:
#           Neighbourhood   Latitude   Longitude
# 114         West Portal  37.741141 -122.465634
# 115    Western Addition  37.779559 -122.429810
# 116  Westwood Highlands   0.000000    0.000000
# 117       Westwood Park   0.000000    0.000000
# 118         Yerba Buena  -5.735634  -79.043992

# %% [markdown]
# We can see now that some neighborhoods have 0s for the longitude and latitude values. We can also see that the last neighborhood is not located in San Francisco (probably due to name being the same as a town in Peru). I'll drop these entries for the simplicity of the task

# %%
sf_coordinates = sf_coordinates[sf_coordinates['Latitude']!=0].iloc[:-1, :]
sf_coordinates
# Out:
#                 Neighbourhood   Latitude   Longitude
# 0                Alamo Square  37.776357 -122.434694
# 1                  Anza Vista  37.780836 -122.443149
# 3                 Balboa Park  37.724949 -122.444805
# 5                     Bayview  37.728889 -122.392500
# 6                Belden Place  37.791744 -122.403886
# 7              Bernal Heights  37.741001 -122.414214
# 8                 Buena Vista  37.806532 -122.420648
# 10                     Castro  37.760856 -122.434957
# 13                China Basin  37.776330 -122.391839
# 14                  Chinatown  37.794301 -122.406376
# 15               Civic Center  37.779594 -122.416794
# 17                Cole Valley  37.765813 -122.449962
# 18             Corona Heights  37.764886 -122.439368
# 19                 Cow Hollow  37.797262 -122.436248
# 20             Crocker-Amazon  37.709378 -122.438587
# 23                   Dogpatch  37.760698 -122.389202
# 24            Dolores Heights  37.745435 -122.424480
# 25            Duboce Triangle  37.767138 -122.432230
# 26                Embarcadero  37.792864 -122.396912
# 28                  Excelsior  37.721794 -122.435382
# 29                   Fillmore  37.784083 -122.433085
# 30         Financial District  37.793647 -122.398938
# 31   Financial District South  37.793647 -122.398938
# 32          Fisherman's Wharf  37.809167 -122.416599
# 33                Forest Hill  37.747431 -122.463583
# 34              Forest Knolls  38.015201 -122.688597
# 35                  Glen Park  37.733104 -122.433805
# 37             Haight-Ashbury  37.770015 -122.446952
# 38               Hayes Valley  37.776685 -122.422936
# 39              Hunters Point  37.726771 -122.371572
# 40                India Basin  37.736042 -122.370526
# 41                  Ingleside  37.722987 -122.453027
# 43               Inner Sunset  37.761450 -122.467643
# 47                  Japantown  37.785579 -122.429809
# 48                Jordan Park  37.784652 -122.456638
# 49               Laguna Honda  37.747977 -122.459117
# 50                Lake Street  37.785705 -122.486230
# 51                   Lakeside  37.730748 -122.475329
# 52                  Lakeshore  37.733037 -122.490249
# 57              Little Saigon  37.784316 -122.416348
# 58              Lone Mountain  37.779096 -122.451916
# 59               Lower Haight  37.771926 -122.432479
# 60      Lower Pacific Heights  37.785767 -122.438904
# 62            Marina District  37.802984 -122.437472
# 68                Mission Bay  37.770774 -122.391171
# 69           Mission District  37.759930 -122.419138
# 73             Mount Davidson  37.738264 -122.453305
# 74                   Nob Hill  37.793262 -122.415249
# 75                 Noe Valley  37.751591 -122.432081
# 76                North Beach  37.801175 -122.409002
# 77         North of Panhandle  37.778408 -122.442599
# 78                  Oceanview  37.713651 -122.457483
# 81            Pacific Heights  37.792717 -122.435644
# 82                 Parkmerced  37.717176 -122.478947
# 83                   Parkside  37.738364 -122.483982
# 84                  Parnassus  37.763513 -122.457806
# 86                    Portola  37.726379 -122.408551
# 87              Portola Place  37.726379 -122.408551
# 88               Potrero Hill  37.756583 -122.399137
# 89                   Presidio  37.798746 -122.464589
# 90           Presidio Heights  37.788751 -122.453027
# 91          Richmond District  37.780643 -122.472596
# 92                Rincon Hill  37.785207 -122.391915
# 93               Russian Hill  37.797707 -122.414971
# 94         Saint Francis Wood  37.734653 -122.468027
# 97             Silver Terrace  37.733854 -122.400028
# 98                South Beach  37.779814 -122.391150
# 100           South of Market  37.780893 -122.400952
# 101                South Park  37.781590 -122.393975
# 102                 Sunnydale  37.709519 -122.404780
# 103                 Sunnyside  37.779281 -122.419236
# 104           Sunset District  37.753542 -122.495249
# 105            Telegraph Hill  37.802730 -122.405851
# 106                Tenderloin  37.784249 -122.413993
# 107           Treasure Island  37.823354 -122.370153
# 108                Twin Peaks  37.754640 -122.446480
# 109              Union Square  37.787936 -122.407517
# 112         Visitacion Valley  37.712132 -122.409713
# 114               West Portal  37.741141 -122.465634
# 115          Western Addition  37.779559 -122.429810

# %% [markdown]
# And now we got it! Let's move on to Los Angeles

# %% [markdown]
# #### Los Angeles Neighbourhoods

# %% [markdown]
# I'll start by scraping the Wikipedia page first

# %%
soup_la = BeautifulSoup(source_la, 'lxml')

# %% [markdown]
# We can see that the names of neighborhoods are marked with li caption. They also have no class or id next to them. We will use it now to get a list of neighbourhoods

# %%
la_hood_list = soup_la.find_all('li',attrs= {'class':None, 'id': None})

# %%
tag_list = []
for hood in la_hood_list:
    tag_list.append(hood.text)

# %% [markdown]
# We still see other entries at the end of this list, I'll cut them out. I will also delete hyperlink residuals at the end of each neighbourhood name

# %%
tag_list = tag_list[:-40]

# %%
clean_la_list = []
for tag in tag_list:
    clean_la_list.append(tag.split('[')[0])

# %% [markdown]
# Now that we have a list of LA neighbourhoods we can put them in a dataframe and then find their coordinates like we did with San Francisco

# %%
la_coordinates = pd.DataFrame(clean_la_list, columns = ['Neighbourhood'])

# %%
la_coordinates['Latitude']=0
la_coordinates['Longitude']=0

# %%
for item in la_coordinates['Neighbourhood']:
    address = '{}, Los Angeles, CA, US'.format(item)
    geolocator_la = Nominatim(user_agent="la_explorer")
    location_la = geolocator_la.geocode(address)
    if location_la is not None:
        la_coordinates['Latitude'].loc[la_coordinates['Neighbourhood']==item] = location_la.latitude
        la_coordinates['Longitude'].loc[la_coordinates['Neighbourhood']==item] = location_la.longitude
# Out:
# /Users/Anna/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# And now I'll just cut all the neighborhoods, whose coordinates weren't found

# %%
la_coordinates = la_coordinates[la_coordinates['Latitude']!=0]
la_coordinates
# Out:
#               Neighbourhood   Latitude   Longitude
# 0          Angelino Heights  34.070289 -118.254796
# 1                    Arleta  34.241327 -118.432205
# 3             Arts District  34.041239 -118.234450
# 4           Atwater Village  34.116398 -118.256464
# 5             Baldwin Hills  34.007568 -118.350596
# 13             Beverly Glen  34.107785 -118.445636
# 16             Beverly Park  34.063769 -118.264690
# 17              Beverlywood  34.046633 -118.395038
# 18            Boyle Heights  34.033166 -118.204865
# 19                Brentwood  34.052140 -118.474070
# 23                Brookside  34.053683 -118.242767
# 24              Bunker Hill  34.055066 -118.251223
# 25            Cahuenga Pass  34.132541 -118.354191
# 26              Canoga Park  34.201078 -118.597826
# 27        Canterbury Knolls  33.842760 -118.129731
# 28                  Carthay  34.056121 -118.373411
# 30          Central-Alameda  33.972132 -118.233322
# 32             Century City  34.055565 -118.417856
# 33               Chatsworth  34.259571 -118.602325
# 36                Chinatown  34.063459 -118.236050
# 37             Civic Center  34.057466 -118.246796
# 38                 Crenshaw  33.925212 -118.326530
# 40             Cypress Park  34.092232 -118.224518
# 41                  Del Rey  33.985290 -118.425355
# 42                 Downtown  33.739710 -118.278765
# 43               Eagle Rock  33.472374 -118.605348
# 46                Echo Park  34.074000 -118.260874
# 47                 Edendale  34.107516 -118.265949
# 48                El Sereno  34.081121 -118.177849
# 49          Elysian Heights  34.082898 -118.234413
# 50             Elysian Park  34.082898 -118.234413
# 52                   Encino  34.159132 -118.501617
# 53          Exposition Park  34.015651 -118.287180
# 55                  Fairfax  34.064874 -118.361378
# 56         Fashion District  34.036622 -118.259069
# 58       Financial District  34.050248 -118.255775
# 59                 Florence  33.975217 -118.265911
# 62              Gallery Row  34.046687 -118.249490
# 63                 Garvanza  34.119578 -118.180626
# 64            Glassell Park  34.116120 -118.228963
# 65            Gramercy Park  34.033939 -118.312432
# 66            Granada Hills  34.296279 -118.505899
# 68            Griffith Park  34.134427 -118.305092
# 69             Hancock Park  34.063729 -118.356104
# 70              Harbor City  33.791350 -118.291380
# 72          Harvard Heights  34.072417 -118.288209
# 74                   Hermon  34.107314 -118.185251
# 75            Highland Park  34.109947 -118.196983
# 77                Hollywood  34.093214 -118.319612
# 79          Hollywood Hills  34.131179 -118.335547
# 80     Hollywood Hills West  34.131179 -118.335547
# 82                Hyde Park  33.980569 -118.330631
# 83           Jefferson Park  34.027234 -118.317576
# 84         Jewelry District  34.046206 -118.254167
# 86                Koreatown  34.058013 -118.300809
# 87                   Ladera  33.994179 -118.375354
# 89              Lake Balboa  34.181166 -118.495236
# 90        Lake View Terrace  34.276391 -118.361191
# 91                Larchmont  34.079316 -118.323649
# 92            Laurel Canyon  34.168465 -118.396296
# 93             Leimert Park  34.007702 -118.332063
# 94          Lincoln Heights  34.070566 -118.205073
# 95           Little Armenia  34.100979 -118.312566
# 97             Little Tokyo  34.048157 -118.241261
# 98                Los Feliz  34.108154 -118.289943
# 99        Manchester Square  33.949798 -118.374002
# 100       Mandeville Canyon  34.061039 -118.494980
# 102               Mar Vista  34.003760 -118.439164
# 105            Mid-Wilshire  34.061943 -118.298731
# 107           Mission Hills  34.257225 -118.467028
# 111        Mount Washington  34.098840 -118.221107
# 114             North Hills  34.239054 -118.478622
# 115         North Hollywood  34.172904 -118.374037
# 116              Northridge  34.228592 -118.536932
# 120       Pacific Palisades  34.048064 -118.526471
# 121                 Pacoima  34.262502 -118.427027
# 122                   Palms  34.021543 -118.414635
# 123           Panorama City  34.224290 -118.445374
# 124            Park La Brea  34.067402 -118.355236
# 127              Pico-Union  34.041072 -118.284448
# 129           Playa del Rey  33.955083 -118.436750
# 130             Playa Vista  33.972790 -118.427578
# 131            Porter Ranch  34.277253 -118.548402
# 132             Rancho Park  34.145907 -117.890425
# 133                  Reseda  34.201116 -118.536474
# 136           Rustic Canyon  34.077760 -118.518924
# 137               San Pedro  33.735852 -118.292293
# 138                Sawtelle  34.036111 -118.450356
# 139            Shadow Hills  34.261947 -118.351746
# 140            Sherman Oaks  34.150872 -118.448987
# 142             Silver Lake  34.089652 -118.269374
# 143                Skid Row  34.044057 -118.243851
# 146              South Park  34.040407 -118.266538
# 149             Studio City  34.148399 -118.396188
# 150                 Sunland  34.266947 -118.302300
# 151         Sunset Junction  34.092649 -118.280795
# 152              Sun Valley  34.217504 -118.370358
# 153                  Sylmar  34.307625 -118.449215
# 154                 Tarzana  34.172735 -118.553384
# 155         Terminal Island  33.745106 -118.263022
# 157             Toluca Lake  34.146788 -118.349107
# 158            Toy District  34.047000 -118.245476
# 159                 Tujunga  34.252225 -118.288410
# 160        University Hills  34.066649 -118.177440
# 161         University Park  34.128292 -117.885557
# 162  University Park, North  34.128292 -117.885557
# 164          Valley Village  34.161972 -118.402431
# 165                Van Nuys  34.186658 -118.448729
# 166                  Venice  33.995044 -118.466887
# 169          Vermont Square  34.000140 -118.295890
# 172           Victoria Park  34.053683 -118.242767
# 173           Village Green  34.019871 -118.360664
# 175           Warner Center  34.181146 -118.597442
# 176                   Watts  33.940567 -118.242848
# 178             Westchester  33.959735 -118.400632
# 179                Westdale  34.030389 -118.432012
# 181              West Hills  34.203232 -118.645476
# 182                Westlake  34.058144 -118.277892
# 183        West Los Angeles  34.046399 -118.448135
# 185                Westwood  34.056121 -118.430635
# 186        Westwood Village  34.059454 -118.444246
# 189              Wilmington  33.780018 -118.262571
# 190         Wilshire Center  34.061515 -118.432771
# 192          Windsor Square  34.072593 -118.320810
# 193                Winnetka  34.201262 -118.571087
# 194          Woodland Hills  34.168436 -118.605838

# %% [markdown]
# We have it! Let's do the same for San Diego

# %% [markdown]
# #### Getting location data for San Diego

# %%
soup_sd = BeautifulSoup(source_sd, 'lxml')

# %% [markdown]
# Similar to LA list, San Diego neighbourhoods are marked by li caption and have no class or id. So, I'll just repeat procedure I did for LA

# %%
sd_hood_list = soup_sd.find_all('li', attrs = {'class':None, 'id':None})

# %%
tag_list = []
for hood in sd_hood_list:
    tag_list.append(hood.text)

# %% [markdown]
# We have a list, but it also contains some entries that are not neighbourhoods. It makes sense because this page had neighbourhoods and communities on it. Neighbourhoods are at the very bottom of the list, so I'll try to keep just them. I will also make the names look clean and sort out double entries

# %%
cleaner_list = tag_list[-139:-22]

# %%
sd_list = []
for entry in cleaner_list:
    if '(' in entry:
        sd_list.append(entry.split('(')[0])
    elif ')' in entry:
        sd_list.append(entry.split(')')[0])
    else:
        sd_list.append(entry)

# %% [markdown]
# We can now create the dataframe and get coordinates

# %%
sd_coordinates = pd.DataFrame(sd_list, columns = ['Neighbourhood'])

# %%
sd_coordinates['Latitude']=0
sd_coordinates['Longitude']=0

# %%
for item in sd_coordinates['Neighbourhood']:
    address = '{}, San Diego, CA, US'.format(item)
    geolocator_sd = Nominatim(user_agent="sd_explorer")
    location_sd = geolocator_sd.geocode(address)
    if location_sd is not None:
        sd_coordinates['Latitude'].loc[sd_coordinates['Neighbourhood']==item] = location_sd.latitude
        sd_coordinates['Longitude'].loc[sd_coordinates['Neighbourhood']==item] = location_sd.longitude
# Out:
# /Users/Anna/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sd_coordinates = sd_coordinates[sd_coordinates['Latitude']!=0]
sd_coordinates
# Out:
#                Neighbourhood   Latitude   Longitude
# 1                   Bay Park  32.784638 -117.202605
# 2              Carmel Valley  32.943434 -117.213979
# 3                 Clairemont  32.819505 -117.182340
# 4            Del Mar Heights  32.948811 -117.250785
# 5               Del Mar Mesa  32.941434 -117.182535
# 6                   La Jolla  32.832590 -117.271684
# 8              Mission Beach  32.782557 -117.252592
# 10             Pacific Beach  32.797827 -117.240318
# 11   Pacific Highlands Ranch  32.964098 -117.191977
# 12              Torrey Hills  32.913769 -117.225549
# 13              Torrey Pines  32.891957 -117.240255
# 14           University City  32.872650 -117.214023
# 15       Village of La Jolla  32.844334 -117.270922
# 16      Black Mountain Ranch  32.984117 -117.131932
# 17     Carmel Mountain Ranch  32.980393 -117.078364
# 18                 Mira Mesa  32.915602 -117.143923
# 19                   Miramar  32.893658 -117.118366
# 20           Rancho Bernardo  33.018610 -117.061049
# 21          Rancho Encantada  32.924815 -117.022173
# 22        Rancho Peñasquitos  32.957710 -117.128540
# 23             Sabre Springs  32.953379 -117.094477
# 24        San Pasqual Valley  33.091034 -116.999002
# 25             Scripps Ranch  32.902269 -117.099755
# 26           Sorrento Valley  32.900141 -117.189446
# 27             Sorrento Mesa  32.767829 -117.023084
# 28          Torrey Highlands  32.964121 -117.156751
# 29                  Birdland  32.792333 -117.154206
# 31               Kearny Mesa  32.828924 -117.142415
# 32       Mission Valley East  32.770502 -117.154070
# 33                   Navajo   32.800908 -117.059085
# 34                 Del Cerro  32.785035 -117.062482
# 35                Grantville  32.787550 -117.097253
# 36                San Carlos  32.803386 -117.038392
# 37                Serra Mesa  32.802899 -117.138774
# 38               Tierrasanta  32.829215 -117.103643
# 39                Burlingame  32.731660 -117.129321
# 40                Hillcrest   32.748290 -117.160976
# 41               Linda Vista  32.789841 -117.167646
# 42                   Midtown  32.747933 -117.165373
# 43             Mission Hills  32.752951 -117.183521
# 44       Mission Valley West  32.770502 -117.154070
# 45                    Morena  32.766666 -117.195861
# 46                North Park  32.748388 -117.130156
# 47               Ocean Beach  32.744807 -117.247607
# 48                  Old Town  32.755328 -117.197865
# 49               Point Loma   32.726526 -117.244454
# 50           Liberty Station  32.738105 -117.214274
# 51               Loma Portal  32.746213 -117.214719
# 52                    Midway  32.717421 -117.162771
# 54      Roseville-Fleetridge  32.729706 -117.238822
# 55             Sunset Cliffs  32.730500 -117.253200
# 56               Wooded Area  32.719170 -117.246631
# 57        University Heights  32.757194 -117.146043
# 58                 Downtown   33.125353 -117.075213
# 59                      Core  32.717277 -117.159680
# 60               Cortez Hill  32.721465 -117.159809
# 61              East Village  32.713731 -117.153640
# 62           Gaslamp Quarter  32.711486 -117.160111
# 63                Harborview  32.725750 -117.171852
# 64              Little Italy  32.723458 -117.168272
# 65                    Marina  32.785738 -117.041678
# 66               Balboa Park  32.731357 -117.146527
# 67              Bankers Hill  32.728293 -117.162105
# 68              Barrio Logan  32.693886 -117.138007
# 69               Golden Hill  32.716163 -117.136143
# 70                Grant Hill  32.708666 -117.133925
# 71             Logan Heights  32.699219 -117.129476
# 72                  Memorial  32.731139 -117.158395
# 73                Middletown  32.734015 -117.175147
# 74           Sherman Heights  32.710607 -117.142255
# 75                South Park  32.724443 -117.129178
# 76                  Stockton  32.713385 -117.123087
# 77              City Heights  32.749728 -117.101029
# 79                El Cerrito  32.717421 -117.162771
# 80            Fairmount Park  32.723375 -117.107629
# 81                   Gateway  32.872825 -117.206364
# 82                  Islenair  32.733175 -117.099658
# 83                Kensington  32.763319 -117.106413
# 84            Normal Heights  32.759274 -117.117512
# 85                  Oak Park  32.737179 -117.070855
# 87                   Rolando  32.760591 -117.058728
# 88              Rolando Park  32.748630 -117.057244
# 90                  Talmadge  32.759158 -117.089006
# 91                   Webster  32.721534 -117.093773
# 92                Alta Vista  32.693339 -117.063154
# 93              Bay Terraces  32.691914 -117.036631
# 94          Broadway Heights  32.729770 -117.059026
# 95              Chollas View  32.713108 -117.091141
# 96             Emerald Hills  32.716719 -117.081141
# 97                   Encanto  32.711997 -117.050306
# 98                   Jamacha  32.714962 -117.040885
# 99              Lincoln Park  32.704219 -117.089474
# 100                   Lomita  32.708664 -117.028639
# 101            Mountain View  32.699219 -117.112809
# 102               Mount Hope  32.714219 -117.107531
# 103           Paradise Hills  32.678387 -117.056973
# 104                Shelltown  32.686084 -117.107731
# 105                  Skyline  32.702661 -117.030632
# 106               Southcrest  32.691092 -117.117173
# 107            Valencia Park  32.704774 -117.085030
# 108                   Border  32.543817 -117.046425
# 110                   Nestor  32.576410 -117.084170
# 112                Otay Mesa  32.560058 -116.936134
# 113           Otay Mesa West  32.573391 -117.054195
# 114                Palm City  32.584137 -117.083809
# 115               San Ysidro  32.552001 -117.043081
# 116     Tijuana River Valley  32.558405 -117.092965

# %% [markdown]
# And we're done scrapping and searching!

# %% [markdown]
# ### Part 3: Getting the Venues

# %%
sf_coordinates['City']='San Francisco'
la_coordinates['City']='Los Angeles'
sd_coordinates['City']='San Diego'
# Out:
# /Users/Anna/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Anna/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 274                Middletown  32.734015 -117.175147      San Diego
# 275           Sherman Heights  32.710607 -117.142255      San Diego
# 276                South Park  32.724443 -117.129178      San Diego
# 277                  Stockton  32.713385 -117.123087      San Diego
# 278              City Heights  32.749728 -117.101029      San Diego
# 279                El Cerrito  32.717421 -117.162771      San Diego
# 280            Fairmount Park  32.723375 -117.107629      San Diego
# 281                   Gateway  32.872825 -117.206364      San Diego
# 282                  Islenair  32.733175 -117.099658      San Diego
# 283                Kensington  32.763319 -117.106413      San Diego
# 284            Normal Heights  32.759274 -117.117512      San Diego
# 285                  Oak Park  32.737179 -117.070855      San Diego
# 286                   Rolando  32.760591 -117.058728      San Diego
# 287              Rolando Park  32.748630 -117.057244      San Diego
# 288                  Talmadge  32.759158 -117.089006      San Diego
# 289                   Webster  32.721534 -117.093773      San Diego
# 290                Alta Vista  32.693339 -117.063154      San Diego
# 291              Bay Terraces  32.691914 -117.036631      San Diego
# 292          Broadway Heights  32.729770 -117.059026      San Diego
# 293              Chollas View  32.713108 -117.091141      San Diego
# 294             Emerald Hills  32.716719 -117.081141      San Diego
# 295                   Encanto  32.711997 -117.050306      San Diego
# 296                   Jamacha  32.714962 -117.040885      San Diego
# 297              Lincoln Park  32.704219 -117.089474      San Diego
# 298                    Lomita  32.708664 -117.028639      San Diego
# 299             Mountain View  32.699219 -117.112809      San Diego
# 300                Mount Hope  32.714219 -117.107531      San Diego
# 301            Paradise Hills  32.678387 -117.056973      San Diego
# 302                 Shelltown  32.686084 -117.107731      San Diego
# 303                   Skyline  32.702661 -117.030632      San Diego
# 304                Southcrest  32.691092 -117.117173      San Diego
# 305             Valencia Park  32.704774 -117.085030      San Diego
# 306                    Border  32.543817 -117.046425      San Diego
# 307                    Nestor  32.576410 -117.084170      San Diego
# 308                 Otay Mesa  32.560058 -116.936134      San Diego
# 309            Otay Mesa West  32.573391 -117.054195      San Diego
# 310                 Palm City  32.584137 -117.083809      San Diego
# 311                San Ysidro  32.552001 -117.043081      San Diego
# 312      Tijuana River Valley  32.558405 -117.092965      San Diego

# %% [markdown]
# ##### Initialize Foursquare credentials

# %%
CLIENT_ID = 'U2NNANEUQUQ2NFUN2N25XHS1A4GLC0J15D2LIISWSIYLEKF0' # your Foursquare ID
CLIENT_SECRET = 'GY5UVEHHCPD5DUXCTHI0MXWVDO5ND4OWAO3SMMMWYX2NZNVT' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: U2NNANEUQUQ2NFUN2N25XHS1A4GLC0J15D2LIISWSIYLEKF0
# CLIENT_SECRET:GY5UVEHHCPD5DUXCTHI0MXWVDO5ND4OWAO3SMMMWYX2NZNVT

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
west_coast_venues = getNearbyVenues(names=all_cities['Neighbourhood'],
                                   latitudes=all_cities['Latitude'],
                                   longitudes=all_cities['Longitude']
                                  )
# Out:
# Alamo Square
# Anza Vista
# Balboa Park
# Bayview
# Belden Place
# Bernal Heights
# Buena Vista
# Castro
# China Basin
# Chinatown
# Civic Center
# Cole Valley
# Corona Heights
# Cow Hollow
# Crocker-Amazon
# Dogpatch
# Dolores Heights
# Duboce Triangle
# Embarcadero
# Excelsior
# Carmel Mountain Ranch
# Mira Mesa
# Miramar
# Rancho Bernardo
# Rancho Encantada
# Rancho Peñasquitos
# Sabre Springs
# San Pasqual Valley
# Scripps Ranch
# Sorrento Valley
# Sorrento Mesa
# Torrey Highlands
# Birdland
# Kearny Mesa
# Mission Valley East
# Navajo
# Del Cerro
# Grantville
# San Carlos
# Serra Mesa
# Tierrasanta
# Burlingame
# Hillcrest
# Linda Vista
# Midtown
# Mission Hills
# Mission Valley West
# Morena
# North Park
# Ocean Beach
# Old Town
# Point Loma
# Liberty Station
# Loma Portal
# Midway
# Roseville-Fleetridge
# Sunset Cliffs
# Wooded Area
# University Heights
# Downtown
# Core
# Cortez Hill
# East Village
# Gaslamp Quarter
# Harborview
# Little Italy
# Marina
# Balboa Park
# Bankers Hill
# Barrio Logan
# Golden Hill
# Grant Hill
# Logan Heights
# Memorial
# Middletown
# Sherman Heights
# South Park
# Stockton
# City Heights
# El Cerrito
# Fairmount Park
# Gateway
# Islenair
# Kensington
# Normal Heights
# Oak Park
# Rolando
# Rolando Park
# Talmadge
# Webster
# Alta Vista
# Bay Terraces
# Broadway Heights
# Chollas View
# Emerald Hills
# Encanto
# Jamacha
# Lincoln Park
# Lomita
# Mountain View
# Mount Hope
# Paradise Hills
# Shelltown
# Skyline
# Southcrest
# Valencia Park
# Border
# Nestor
# Otay Mesa
# Otay Mesa West
# Palm City
# San Ysidro
# Tijuana River Valley

# %%
print(west_coast_venues.shape)
west_coast_venues.head()
# Out:
# (9981, 7)
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Alamo Square              37.776357             -122.434694
# 1  Alamo Square              37.776357             -122.434694
# 2  Alamo Square              37.776357             -122.434694
# 3  Alamo Square              37.776357             -122.434694
# 4  Alamo Square              37.776357             -122.434694
#
#                    Venue  Venue Latitude  Venue Longitude Venue Category
# 0           Alamo Square       37.776062      -122.433622           Park
# 1         Painted Ladies       37.776120      -122.433389  Historic Site
# 2  Alamo Square Dog Park       37.775878      -122.435740        Dog Run
# 3        The Independent       37.775573      -122.437835      Rock Club
# 4               The Mill       37.776425      -122.437970         Bakery

# %%
print('There are {} uniques categories.'.format(len(west_coast_venues['Venue Category'].unique())))
# Out:
# There are 430 uniques categories.

# %%
west_coast_venues_cities = west_coast_venues.merge(all_cities, how='left', left_on = ['Neighborhood', 'Neighborhood Latitude', 'Neighborhood Longitude'], right_on=['Neighbourhood', 'Latitude', 'Longitude'])

# %%
west_coast_venues_cities= west_coast_venues_cities.drop(['Neighbourhood', 'Latitude', 'Longitude'], axis=1)

# %%
west_coast_venues_cities.shape
# Out:
# (9981, 8)

# %%
west_coast_venues_cities.head()
# Out:
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Alamo Square              37.776357             -122.434694
# 1  Alamo Square              37.776357             -122.434694
# 2  Alamo Square              37.776357             -122.434694
# 3  Alamo Square              37.776357             -122.434694
# 4  Alamo Square              37.776357             -122.434694
#
#                    Venue  Venue Latitude  Venue Longitude Venue Category  \
# 0           Alamo Square       37.776062      -122.433622           Park
# 1         Painted Ladies       37.776120      -122.433389  Historic Site
# 2  Alamo Square Dog Park       37.775878      -122.435740        Dog Run
# 3        The Independent       37.775573      -122.437835      Rock Club
# 4               The Mill       37.776425      -122.437970         Bakery
#
#             City
# 0  San Francisco
# 1  San Francisco
# 2  San Francisco
# 3  San Francisco
# 4  San Francisco
